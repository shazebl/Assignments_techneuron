# %%
"""

1. What exactly is []?

[] is a list data type which can be used to store a set of values of any data type.

example code:

lst=['shazeb',8675947699,True]

2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

spam.insert(2,'hello')

Explanation: Inserts 'hello' in the index position 2.

--------------------------------------------------------------------------------------------
Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.
--------------------------------------------------------------------------------------------

3. What is the value of spam[int(int('3'*2)/11)]

Answer: 'd'

Explanation: int(int('3'*2)/11) will give value = 3. spam[3]='d' 

4. What is the value of spam[-1]?

Answer: 'd'

Explanation: Index value -1 mean that the last element of the list

5. What is the value of spam[:2]?

Answer: ['a','b']

Explanation: It's called list slicing and the index values 0 to 1 will be called.

----------------------------------------------------------------------------------------------
Let's pretend bacon has the list [3.14, 'cat', 11, 'cat', True] for the next three questions.
----------------------------------------------------------------------------------------------

6. What is the value of bacon.index('cat')?

Answer: 1

Explanation: It wil return the index of the first occurence of string cat

7. How does bacon.append(99) change the look of the list value in bacon?

Answer: [3.14, 'cat', 11, 'cat', True, 99]

Explanation: append function will add 99 to the last.

8. How does bacon.remove('cat') change the look of the list in bacon?

Answer: [3.14, 11, 'cat', True, 99]

Explanation: remove function will delete the first instance of cat and shift others front.

9. What are the list concatenation and list replication operators?

List concatenation: +   

Code:
[1,2,3] + [4,5,6]

----------------------------------

List replication:   *

Code:
[1,2,3]*3

----------------------------------

10. What is difference between the list methods append() and insert()?

append(10) method will add the value to the end of the list

insert(2,10) method will add the value 10 at the index position of 2 in the list. First argument denotes index position where value has to be inserted and second argument denotes the value to be inserted.

11. What are the two methods for removing items from a list?

a=[1,2,3,4]
a.remove(2)   - This method will remove the integer 2 from the list. Remove method will remove the argument given.

a=[1,2,3,4]   
a.pop()       - This method will by default remove the last index value from the list. If the index value is explicitly mentioned then that index value will be removed.

12. Describe how list values and string values are identical.

List value and string values are identical because they both are ordered list of elements.

13. What's the difference between tuples and lists?

Tuples data type are immutable  and list data type are mutable.

14. How do you type a tuple value that only contains the integer 42?

a=(42,)  If comma is not given, then it will be considered as a integer

15. How do you get a list value's tuple form? How do you get a tuple value's list form?

List of tuples:
a=[(1,2),(3,4),(5,6)]

Tuples of list:
a=([1,2],[3,4],[5,6])

16. Variables that contain list values are not necessarily lists themselves. Instead, what do they
contain?

Variables that contain list values only store the reference to the list values.
Variables that contain integer or string values store the values itself.

17. How do you distinguish between copy.copy() and copy.deepcopy()?

copy.copy() method is used to create a reference of the object and any changes made to the object created using copy.copy() changes the original object.

copy.deepcopy() mehtod is used to create a seperate copy of the object and any changes made to the object created using copu.deepcopy() is not reflected in the original object.

"""
