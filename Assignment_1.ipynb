# %%
""""

1) In the below elements which of them are values or an expression.

*       - Expression
'hello' - Value (string)
-87.8   - Value (floating point number)
-       - Expression
/       - Expression
+       - Expression
6       - Value (integer)

2) What is the difference between string and variable?

String is a immutable data type which is used to represent the characters. 
Variable or object is used to store the values of various data types (string, int, float, etc.) into the RAM.

3) Describe three different data types?

Integer
List
String
 
4) What is an expression made up of? What do all expressions do?

An expression is made up of mathematical, logical, conditional, boolean operators, etc.
Boolean expressions gives True/False values.
Mathematical operators perform addition, subtraction, etc.
Contional expressions check the conditions and excute the code.
Logical expressions use AND OR truth tables and give results.

5) This assignment statements, like spam = 10. What is the difference between an expression and a statement?

A statement refers to defining a operation such as assigning a particular value to a variable or defining a variable or perfoming conditional operations.
Expression refers to the type of operation performed. Ex: spam = 10 (= is an expression which assigns the value 10 to the variable spam).

6) After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1

The value of bacon variable = 22 since the value of the addition operation is not stored in bacon.

7) What should the values of the following two terms be?

'spam' + 'spamspam' = 'spamspamspam'
'spam' * 3          = 'spamspamspam'

8) Why is eggs a valid variable name while 100 is invalid?

In python that the variable name should not start with a number.
100 is not considered as a varibale name because it is a value.
Eggs is a valid variable name because it is not a keyword and does not start with a number.

9) What three functions can be used to get the integer, floating-point number, or string
version of a value?

Integer                  - int()
Floating point number    - float()
String                   - str()

10) Why does this expression cause an error? How can you fix it?
'I have eaten' + 99 + 'burritos'

99 is of integer data type and cannot be concatenated with string data type.
You can fix it by converting 99 of integer data type to string data type by:
Enclosing 99 into single/double quotes -  'I have eaten' + '99' + 'burritos'
Converting 99 to string data type      - 'I have eaten' + str(99) + 'burritos'

"""
